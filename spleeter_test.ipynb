# %% [markdown]
# spleeterインストール

# %%
# !apt install ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# 0 upgraded, 0 newly installed, 0 to remove and 37 not upgraded.

# %%
pip install spleeter
# Out:
# ...
#      |████████████████████████████████| 51 kB 3.1 MB/s
# ...
#      |████████████████████████████████| 25.3 MB 1.6 MB/s
# ...
#      |████████████████████████████████| 183 kB 32.4 MB/s
# ...
#      |████████████████████████████████| 454.3 MB 14 kB/s
# ...
#      |████████████████████████████████| 77 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 1.2 MB 44.7 MB/s
# ...
#      |████████████████████████████████| 4.0 MB 30.6 MB/s
# ...
#      |████████████████████████████████| 462 kB 41.4 MB/s
# ...
#      |████████████████████████████████| 58 kB 6.1 MB/s
# ...
#      |████████████████████████████████| 57 kB 5.1 MB/s
# ...
#      |████████████████████████████████| 54 kB 3.2 MB/s
# ...
#      |████████████████████████████████| 78 kB 5.6 MB/s
# ...
#      |████████████████████████████████| 3.3 MB 43.3 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 65.8 MB/s
# ...
#      |████████████████████████████████| 3.4 MB 12.4 MB/s
# ...
#      |████████████████████████████████| 97 kB 6.3 MB/s
# ...

# %%
from IPython.display import Audio

# %% [markdown]
# spleeter公式音源の分離

# %%
# !wget https://github.com/deezer/spleeter/raw/master/audio_example.mp3
# Out:
# --2021-12-14 13:57:39--  https://github.com/deezer/spleeter/raw/master/audio_example.mp3
# Resolving github.com (github.com)... 140.82.114.4
# Connecting to github.com (github.com)|140.82.114.4|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://raw.githubusercontent.com/deezer/spleeter/master/audio_example.mp3 [following]
# --2021-12-14 13:57:39--  https://raw.githubusercontent.com/deezer/spleeter/master/audio_example.mp3
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.108.133, 185.199.109.133, 185.199.110.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.108.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 262867 (257K) [audio/mpeg]
# Saving to: ‘audio_example.mp3’
#
# audio_example.mp3   100%[===================>] 256.71K  --.-KB/s    in 0.03s
#
# 2021-12-14 13:57:39 (7.96 MB/s) - ‘audio_example.mp3’ saved [262867/262867]

# %%
#上のはただの音源追加

# %%
Audio('audio_example.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
# !spleeter separate -h
# Out:
# Usage: spleeter separate [OPTIONS] FILES...
# Try 'spleeter separate --help' for help.
#
# Error: no such option: -h

# %%
# !spleeter separate -o output/ audio_example.mp3
# Out:
# INFO:spleeter:Downloading model archive https://github.com/deezer/spleeter/releases/download/v1.4.0/2stems.tar.gz
# INFO:spleeter:Validating archive checksum
# INFO:spleeter:Extracting downloaded 2stems archive
# INFO:spleeter:2stems model file(s) extracted
# INFO:spleeter:File output/audio_example/vocals.wav written succesfully
# INFO:spleeter:File output/audio_example/accompaniment.wav written succesfully

# %%
# !spleeter separate -o output/ senbon.wav
# Out:
# INFO:spleeter:File output/senbon/vocals.wav written succesfully
# INFO:spleeter:File output/senbon/accompaniment.wav written succesfully

# %%
# !ls output/audio_example
# Out:
# accompaniment.wav  vocals.wav

# %%
Audio('output/audio_example/vocals.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Audio('output/audio_example/accompaniment.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %% [markdown]
# imitation_rain分離

# %%
from google.colab import files

uploaded = files.upload() #ファイルアップロード
# Out:
#      <input type="file" id="files-e8a6e647-70c2-4f3d-8550-b714f5900523" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e8a6e647-70c2-4f3d-8550-b714f5900523">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-6bf772d01a99> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload() #ファイルアップロード
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      61   result = _output.eval_js(
#      62       'google.colab._files._uploadFiles("{input_id}", "{output_id}")'.format(
# ...

# %%
# !ls

# %% [markdown]
# 最後の"stems"の前の数字で分離の仕方が変わる

# %%
# !spleeter separate -i imitation_rain.mp3 -o output/ -p spleeter:2stems

# %%
# !ls output/imitation_rain

# %%
files.download('output/imitation_rain/vocals.wav')

# %%
Audio('output/imitation_rain/vocals.wav')

# %%
Audio('output/imitation_rain/accompaniment.wav')

# %%
Audio('imitation_rain.mp3')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2b7b4acec4dd> in <module>()
# ----> 1 Audio('imitation_rain.mp3')
#
# NameError: name 'Audio' is not defined

# %% [markdown]
# 千本桜分離

# %%
from google.colab import files

# !ls #ディレクトリ移動

# !spleeter separate -i senbon.wav -o output/ -p spleeter:2stems #音源分離&フォルダとファイル生成
# Out:
# drive  sample_data
# Usage: spleeter separate [OPTIONS] FILES...
# Try 'spleeter separate --help' for help.
#
# Error: Missing argument 'FILES...'.

# %%
# !ls output/senbon  #分離した音源が入ったフォルダに移動、フォルダ名は音源ファイル名と一緒

files.download('output/senbon/vocals.wav')  #よくわからん
files.download('output/senbon/accompaniment.wav')
# Out:
# ls: cannot access 'output/senbon': No such file or directory
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-4ffd7108496f> in <module>()
#       1 get_ipython().system('ls output/senbon  #分離した音源が入ったフォルダに移動、フォルダ名は音源ファイル名と一緒')
#       2
# ----> 3 files.download('output/senbon/vocals.wav')  #よくわからん
#       4 files.download('output/senbon/accompaniment.wav')
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in download(filename)
#     140       raise OSError(msg)
#     141     else:
# --> 142       raise FileNotFoundError(msg)  # pylint: disable=undefined-variable
#     143
#     144   comm_manager = _IPython.get_ipython().kernel.comm_manager
#
# FileNotFoundError: Cannot find file: output/senbon/vocals.wav

# %%
Audio('output/senbon/vocals.wav')  #流す

# %%
Audio('output/senbon/accompaniment.wav')

# %%
Audio('senbon.wav')

# %% [markdown]
# 手紙

# %%
from google.colab import files

uploaded = files.upload() #ファイルアップロード
# Out:
#      <input type="file" id="files-5f832c38-fdfa-403b-a35e-a74b56ff1199" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-5f832c38-fdfa-403b-a35e-a74b56ff1199">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# ---------------------------------------------------------------------------
# MessageError                              Traceback (most recent call last)
# <ipython-input-7-6bf772d01a99> in <module>()
#       1 from google.colab import files
#       2
# ----> 3 uploaded = files.upload() #ファイルアップロード
#
# /usr/local/lib/python3.7/dist-packages/google/colab/files.py in upload()
#      69     result = _output.eval_js(
#      70         'google.colab._files._uploadFilesContinue("{output_id}")'.format(
# ---> 71             output_id=output_id))
# ...

# %%
# !ls 

# !spleeter separate -i letter.mp3 -o output/ -p spleeter:2stems
# Out:
# drive		    letter.mp3	pretrained_models  senbon.wav
# imitation_rain.mp3  output	sample_data
# INFO:spleeter:File output/letter/vocals.wav written succesfully
# INFO:spleeter:File output/letter/accompaniment.wav written succesfully

# %%
# !ls output/letter

files.download('output/letter/vocals.wav')
files.download('output/letter/accompaniment.wav')
# Out:
# accompaniment.wav  vocals.wav

# %%
Audio('output/letter/vocals.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Audio('output/letter/accompaniment.wav')
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
Audio('letter.mp3')
# Out:
#                 <audio controls="controls" >
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
