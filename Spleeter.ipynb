# %% [markdown]
# Spleeter

# %%
# !apt install ffmpeg

# %%
pip install spleeter

# %%
from google.colab import files

uploaded = files.upload() #ファイルアップロード

# %%
from IPython.display import Audio



# !ls
#!spleeter separate -o output/ audio_example.mp3
# !spleeter separate -o /content/drive/MyDrive/project4/music_file/ /content/drive/MyDrive/project4/music_file/azakawa1.wav

#Audio('output/azakawa/vocals.wav')

#Audio('output/azakawa/accompaniment.wav')

# %%
def spl(mpath):
  # !spleeter separate -o output/mpath

# %%
mpath = "/content/drive/MyDrive/project4/music_file/imitation_rain(long)2.mp3"

spl(mpath)

# %%
import shutil
import os

#shutil.rmtree('output')
os.remove("audio_example.mp3")

# %% [markdown]
# Open-Unmix

# %%
pip install PySoundFile

# %%
pip list

# %%
pip install openunmix

# %%
# !ls /content/drive/MyDrive/project4/music_file
# Out:
#  azakawa1.wav		      mono_test1.wav	       test
#  imitation_rain1.wav	      teacher_akapera_1m.wav
# 'imitation_rain(long)2.mp3'   teacher_band_1m.wav

# %%
# !umx --model umx azakawa1.wav
# Out:
# Downloading: "https://zenodo.org/api/files/d6105b95-8c52-430c-84ce-bd14b803faaf/vocals-c8df74a5.pth" to /root/.cache/torch/hub/checkpoints/vocals-c8df74a5.pth
# 100% 34.0M/34.0M [00:02<00:00, 12.6MB/s]
# Downloading: "https://zenodo.org/api/files/d6105b95-8c52-430c-84ce-bd14b803faaf/drums-5a48008b.pth" to /root/.cache/torch/hub/checkpoints/drums-5a48008b.pth
# 100% 34.0M/34.0M [00:02<00:00, 13.2MB/s]
# Downloading: "https://zenodo.org/api/files/d6105b95-8c52-430c-84ce-bd14b803faaf/bass-646024d3.pth" to /root/.cache/torch/hub/checkpoints/bass-646024d3.pth
# 100% 34.0M/34.0M [00:02<00:00, 12.0MB/s]
# Downloading: "https://zenodo.org/api/files/d6105b95-8c52-430c-84ce-bd14b803faaf/other-f8e132cc.pth" to /root/.cache/torch/hub/checkpoints/other-f8e132cc.pth
# 100% 34.0M/34.0M [00:02<00:00, 12.5MB/s]
#   0% 0/1 [00:00<?, ?it/s]formats: can't open input file `azakawa1.wav': No such file or directory
#   0% 0/1 [00:00<?, ?it/s]
# Traceback (most recent call last):
# ...

# %%
# !umx --model umx imitation_rain1.wav
# Out:
#   0% 0/1 [00:00<?, ?it/s]formats: can't open input file `imitation_rain1.wav': No such file or directory
#   0% 0/1 [00:00<?, ?it/s]
# Traceback (most recent call last):
#   File "/usr/local/bin/umx", line 8, in <module>
#     sys.exit(separate())
#   File "/usr/local/lib/python3.7/dist-packages/openunmix/cli.py", line 166, in separate
#     audio, rate = data.load_audio(input_file, start=args.start, dur=args.duration)
#   File "/usr/local/lib/python3.7/dist-packages/openunmix/data.py", line 58, in load_audio
#     sig, rate = torchaudio.load(path)
#   File "/usr/local/lib/python3.7/dist-packages/torchaudio/backend/sox_io_backend.py", line 153, in load
#     filepath, frame_offset, num_frames, normalize, channels_first, format)
# RuntimeError: Error loading audio file: failed to open file imitation_rain1.wav
